# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./Coletas/Totosa/Totosa.csv', engine='python')
df = df[(df['Valor do sinal'] <= 1) & (df['Valor do sinal'] >= -1)]
df
# Out:
#        Valor do sinal  Temperatura  Umidade             DataHora
# 0           -0.228516        0.270     0.69  2024-04-03 16:52:53
# 1            0.007812        0.270     0.69  2024-04-03 16:53:10
# 2            0.072266        0.270     0.69  2024-04-03 16:53:26
# 3           -0.210938        0.270     0.69  2024-04-03 16:53:42
# 4           -0.236328        0.270     0.69  2024-04-03 16:53:58
# ...               ...          ...      ...                  ...
# 57646       -0.142578        0.244     0.58  2024-09-29 01:12:34
# 57647       -0.244141        0.244     0.58  2024-09-29 01:12:49
# 57648       -0.021484        0.244     0.58  2024-09-29 01:13:04
# 57649        0.060547        0.244     0.58  2024-09-29 01:13:19
# 57650       -0.195312        0.244     0.58  2024-09-29 01:13:34
#
# [57537 rows x 4 columns]

# %%
df[df['Valor do sinal'] < 1].plot(kind='hist', y='Valor do sinal', figsize=(16, 8))
plt.show()

# %%
df_h_vs = df[df['Valor do sinal'] < 1].copy()
df_h_vs['Hora'] = df_h_vs['Hora'].apply(lambda x: x[:2])
df_h_vs['Valor do sinal'] = pd.cut(
    df_h_vs['Valor do sinal'], bins=[-1.0, -0.75, -0.5, -0.25, 0.0, 0.25, 0.5, 0.75, 1.0], 
    labels=[-1.0, -0.75, -0.5, -0.25, 0.0, 0.25, 0.5, 0.75]
)
df_h_vs['Intensidade'] = df_h_vs['Valor do sinal'].apply(lambda x: abs(x) * 100 if x != 0.0 else 5.0)
df_h_vs.plot(kind='scatter', x='Hora', y='Valor do sinal', s='Intensidade', figsize=(16, 8))
plt.show()

# %%
df_s_1 = df[df['Data'] <= '2024-04-09']
df_s_1.plot(kind='line', x='Data', y=['Valor do sinal', 'Temperatura', 'Umidade'], figsize=(16, 8))
plt.show()

# %%
df_s_2 = df[(df['Data'] < '2024-04-20') & (df['Data'] >= '2024-04-10') & (df['Valor do sinal'] < 1)]
df_s_2.plot(kind='line', x='Data', y=['Valor do sinal', 'Temperatura', 'Umidade'], figsize=(16, 8))
plt.show()

# %%
df_s_3 = df[df['Data'] >= '2024-04-20']
df_s_3.plot(kind='line', x='Data', y=['Valor do sinal', 'Temperatura', 'Umidade'], figsize=(16, 8))
plt.show()

# %%
df_d_1 = df[(df['Data'] >= '2024-04-03') & (df['Data'] <= '2024-04-04')]
df_d_1.plot(kind='line', x='Hora', y=['Valor do sinal', 'Temperatura', 'Umidade'], figsize=(16, 8))
plt.show()

# %%
df_d_2 = df[(df['Data'] >= '2024-04-05') & (df['Data'] <= '2024-04-06')]
df_d_2.plot(kind='line', x='Hora', y=['Valor do sinal', 'Temperatura', 'Umidade'], figsize=(16, 8))
plt.show()

# %%
df_d_3 = df[(df['Data'] >= '2024-04-08') & (df['Data'] <= '2024-04-09')]
df_d_3.plot(kind='line', x='Hora', y=['Valor do sinal', 'Temperatura', 'Umidade'], figsize=(16, 8))
plt.show()

# %%
df_d_3 = df[(df['Data'] >= '2024-04-10') & (df['Data'] <= '2024-04-11') & (df['Valor do sinal'] < 1)]
df_d_3.plot(kind='line', x='Hora', y=['Valor do sinal', 'Temperatura', 'Umidade'], figsize=(16, 8))
plt.show()

# %%
df_d_3 = df[(df['Data'] >= '2024-04-15') & (df['Data'] <= '2024-04-16')]
df_d_3.plot(kind='line', x='Hora', y=['Valor do sinal', 'Temperatura', 'Umidade'], figsize=(16, 8))
plt.show()

# %%
df_d_3 = df[(df['Data'] >= '2024-04-17') & (df['Data'] <= '2024-04-18')]
df_d_3.plot(kind='line', x='Hora', y=['Valor do sinal', 'Temperatura', 'Umidade'], figsize=(16, 8))
plt.show()

# %%
df_d_3 = df[(df['Data'] >= '2024-04-23') & (df['Data'] <= '2024-04-24')]
df_d_3.plot(kind='line', x='Hora', y=['Valor do sinal', 'Temperatura', 'Umidade'], figsize=(16, 8))
plt.show()

# %%
df_d_3 = df[(df['Data'] >= '2024-04-27') & (df['Data'] <= '2024-04-28')]
df_d_3.plot(kind='line', x='Hora', y=['Valor do sinal', 'Temperatura', 'Umidade'], figsize=(16, 8))
plt.show()

# %%
df_d_3 = df[(df['Data'] >= '2024-04-29') & (df['Data'] <= '2024-04-30')]
df_d_3.plot(kind='line', x='Hora', y=['Valor do sinal', 'Temperatura', 'Umidade'], figsize=(16, 8))
plt.show()
